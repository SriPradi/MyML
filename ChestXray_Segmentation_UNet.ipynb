# %% [markdown]
# <a href="https://colab.research.google.com/github/SriPradi/MyML/blob/master/ChestXray_Segmentation_UNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## import required python libraries 
import numpy as np 
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt
from fastai.vision import *

# %%
# mount the data path on gdrive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
root_dir1= "/content/gdrive/My Drive/chest-xray-masks-and-labels/"
# Out:
# Mounted at /content/gdrive

# %%
#  getting the file names
mask_path=Path(root_dir1 + 'masks')
image_path=Path(root_dir1 + 'CXR_png')
test_path=Path(root_dir +'test')

# %%
# Get the file path
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
# check the mask file names with the suffix 'mask'
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %%
# Reading the images and mask from the path
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in tqdm(testing_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    if flag == "train":
        for i in tqdm(training_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test =getData(dim,flag="test")
# Out:
# 100%|██████████| 566/566 [10:19<00:00,  1.10s/it]
# 100%|██████████| 138/138 [02:29<00:00,  1.08s/it]

# %%
# reshaping images and masks
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 256)  524544      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 128 295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#define callbacks
from keras.backend import manual_variable_initialization
manual_variable_initialization(True)
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
from IPython.display import clear_output
from keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4), 
              loss=[dice_coef_loss], 
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0, 
                                                            (mask>127).astype(np.float32), 
                                                            test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg, 
                                                            test_size = 0.1, 
                                                            random_state = 2018)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 16,
                  epochs = 50,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 156s 3s/step - loss: -0.3481 - dice_coef: 0.3482 - binary_accuracy: 0.4570 - val_loss: -0.5008 - val_dice_coef: 0.5008 - val_binary_accuracy: 0.5965
#
# Epoch 00001: val_loss improved from inf to -0.50084, saving model to cxr_reg_weights.best.hdf5
# Epoch 2/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.5463 - dice_coef: 0.5463 - binary_accuracy: 0.6691 - val_loss: -0.6547 - val_dice_coef: 0.6547 - val_binary_accuracy: 0.8130
#
# Epoch 00002: val_loss improved from -0.50084 to -0.65465, saving model to cxr_reg_weights.best.hdf5
# Epoch 3/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.6545 - dice_coef: 0.6545 - binary_accuracy: 0.8056 - val_loss: -0.7130 - val_dice_coef: 0.7130 - val_binary_accuracy: 0.8585
#
# Epoch 00003: val_loss improved from -0.65465 to -0.71302, saving model to cxr_reg_weights.best.hdf5
# Epoch 4/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.6973 - dice_coef: 0.6974 - binary_accuracy: 0.8427 - val_loss: -0.6533 - val_dice_coef: 0.6533 - val_binary_accuracy: 0.8478
#
# Epoch 00004: val_loss did not improve from -0.71302
# Epoch 5/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.7623 - dice_coef: 0.7624 - binary_accuracy: 0.8836 - val_loss: -0.8143 - val_dice_coef: 0.8143 - val_binary_accuracy: 0.9154
#
# Epoch 00005: val_loss improved from -0.71302 to -0.81435, saving model to cxr_reg_weights.best.hdf5
# Epoch 6/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.8708 - dice_coef: 0.8708 - binary_accuracy: 0.9354 - val_loss: -0.9094 - val_dice_coef: 0.9094 - val_binary_accuracy: 0.9543
#
# Epoch 00006: val_loss improved from -0.81435 to -0.90938, saving model to cxr_reg_weights.best.hdf5
# Epoch 7/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9115 - dice_coef: 0.9115 - binary_accuracy: 0.9551 - val_loss: -0.9225 - val_dice_coef: 0.9225 - val_binary_accuracy: 0.9609
#
# Epoch 00007: val_loss improved from -0.90938 to -0.92248, saving model to cxr_reg_weights.best.hdf5
# Epoch 8/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9182 - dice_coef: 0.9182 - binary_accuracy: 0.9586 - val_loss: -0.9253 - val_dice_coef: 0.9253 - val_binary_accuracy: 0.9630
#
# Epoch 00008: val_loss improved from -0.92248 to -0.92526, saving model to cxr_reg_weights.best.hdf5
# Epoch 9/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9227 - dice_coef: 0.9227 - binary_accuracy: 0.9613 - val_loss: -0.9297 - val_dice_coef: 0.9297 - val_binary_accuracy: 0.9637
#
# Epoch 00009: val_loss improved from -0.92526 to -0.92971, saving model to cxr_reg_weights.best.hdf5
# Epoch 10/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9304 - dice_coef: 0.9304 - binary_accuracy: 0.9648 - val_loss: -0.9375 - val_dice_coef: 0.9375 - val_binary_accuracy: 0.9686
#
# Epoch 00010: val_loss improved from -0.92971 to -0.93751, saving model to cxr_reg_weights.best.hdf5
# Epoch 11/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9374 - dice_coef: 0.9374 - binary_accuracy: 0.9685 - val_loss: -0.9418 - val_dice_coef: 0.9418 - val_binary_accuracy: 0.9704
#
# Epoch 00011: val_loss improved from -0.93751 to -0.94178, saving model to cxr_reg_weights.best.hdf5
# Epoch 12/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9408 - dice_coef: 0.9409 - binary_accuracy: 0.9702 - val_loss: -0.9293 - val_dice_coef: 0.9293 - val_binary_accuracy: 0.9655
#
# Epoch 00012: val_loss did not improve from -0.94178
# Epoch 13/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9410 - dice_coef: 0.9410 - binary_accuracy: 0.9707 - val_loss: -0.9479 - val_dice_coef: 0.9479 - val_binary_accuracy: 0.9735
#
# Epoch 00013: val_loss improved from -0.94178 to -0.94795, saving model to cxr_reg_weights.best.hdf5
# Epoch 14/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9485 - dice_coef: 0.9486 - binary_accuracy: 0.9741 - val_loss: -0.9503 - val_dice_coef: 0.9503 - val_binary_accuracy: 0.9747
#
# Epoch 00014: val_loss improved from -0.94795 to -0.95031, saving model to cxr_reg_weights.best.hdf5
# Epoch 15/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9483 - dice_coef: 0.9483 - binary_accuracy: 0.9739 - val_loss: -0.9526 - val_dice_coef: 0.9526 - val_binary_accuracy: 0.9760
#
# Epoch 00015: val_loss improved from -0.95031 to -0.95262, saving model to cxr_reg_weights.best.hdf5
# Epoch 16/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9531 - dice_coef: 0.9531 - binary_accuracy: 0.9761 - val_loss: -0.9536 - val_dice_coef: 0.9536 - val_binary_accuracy: 0.9762
#
# Epoch 00016: val_loss improved from -0.95262 to -0.95356, saving model to cxr_reg_weights.best.hdf5
# Epoch 17/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9505 - dice_coef: 0.9505 - binary_accuracy: 0.9749 - val_loss: -0.9511 - val_dice_coef: 0.9511 - val_binary_accuracy: 0.9751
#
# Epoch 00017: val_loss did not improve from -0.95356
# Epoch 18/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9488 - dice_coef: 0.9488 - binary_accuracy: 0.9742 - val_loss: -0.9553 - val_dice_coef: 0.9553 - val_binary_accuracy: 0.9773
#
# Epoch 00018: val_loss improved from -0.95356 to -0.95533, saving model to cxr_reg_weights.best.hdf5
# Epoch 19/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9546 - dice_coef: 0.9546 - binary_accuracy: 0.9772 - val_loss: -0.9569 - val_dice_coef: 0.9569 - val_binary_accuracy: 0.9780
#
# Epoch 00019: val_loss improved from -0.95533 to -0.95693, saving model to cxr_reg_weights.best.hdf5
# Epoch 20/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9558 - dice_coef: 0.9558 - binary_accuracy: 0.9776 - val_loss: -0.9581 - val_dice_coef: 0.9581 - val_binary_accuracy: 0.9786
#
# Epoch 00020: val_loss improved from -0.95693 to -0.95807, saving model to cxr_reg_weights.best.hdf5
# Epoch 21/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9560 - dice_coef: 0.9560 - binary_accuracy: 0.9778 - val_loss: -0.9564 - val_dice_coef: 0.9564 - val_binary_accuracy: 0.9781
#
# Epoch 00021: val_loss did not improve from -0.95807
# Epoch 22/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9561 - dice_coef: 0.9561 - binary_accuracy: 0.9779 - val_loss: -0.9578 - val_dice_coef: 0.9578 - val_binary_accuracy: 0.9786
#
# Epoch 00022: val_loss did not improve from -0.95807
# Epoch 23/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9594 - dice_coef: 0.9594 - binary_accuracy: 0.9796 - val_loss: -0.9594 - val_dice_coef: 0.9594 - val_binary_accuracy: 0.9793
#
# Epoch 00023: val_loss improved from -0.95807 to -0.95940, saving model to cxr_reg_weights.best.hdf5
# Epoch 24/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9604 - dice_coef: 0.9604 - binary_accuracy: 0.9803 - val_loss: -0.9599 - val_dice_coef: 0.9599 - val_binary_accuracy: 0.9797
#
# Epoch 00024: val_loss improved from -0.95940 to -0.95987, saving model to cxr_reg_weights.best.hdf5
# Epoch 25/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9614 - dice_coef: 0.9614 - binary_accuracy: 0.9808 - val_loss: -0.9604 - val_dice_coef: 0.9604 - val_binary_accuracy: 0.9799
#
# Epoch 00025: val_loss improved from -0.95987 to -0.96040, saving model to cxr_reg_weights.best.hdf5
# Epoch 26/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9598 - dice_coef: 0.9598 - binary_accuracy: 0.9797 - val_loss: -0.9556 - val_dice_coef: 0.9556 - val_binary_accuracy: 0.9772
#
# Epoch 00026: val_loss did not improve from -0.96040
# Epoch 27/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9788 - val_loss: -0.9595 - val_dice_coef: 0.9595 - val_binary_accuracy: 0.9794
#
# Epoch 00027: val_loss did not improve from -0.96040
# Epoch 28/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9566 - dice_coef: 0.9566 - binary_accuracy: 0.9783 - val_loss: -0.9583 - val_dice_coef: 0.9583 - val_binary_accuracy: 0.9791
#
# Epoch 00028: val_loss did not improve from -0.96040
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 29/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9604 - dice_coef: 0.9604 - binary_accuracy: 0.9801 - val_loss: -0.9604 - val_dice_coef: 0.9604 - val_binary_accuracy: 0.9801
#
# Epoch 00029: val_loss improved from -0.96040 to -0.96041, saving model to cxr_reg_weights.best.hdf5
# Epoch 30/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9629 - dice_coef: 0.9629 - binary_accuracy: 0.9812 - val_loss: -0.9613 - val_dice_coef: 0.9613 - val_binary_accuracy: 0.9804
#
# Epoch 00030: val_loss improved from -0.96041 to -0.96126, saving model to cxr_reg_weights.best.hdf5
# Epoch 31/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9623 - dice_coef: 0.9623 - binary_accuracy: 0.9814 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9809
#
# Epoch 00031: val_loss improved from -0.96126 to -0.96255, saving model to cxr_reg_weights.best.hdf5
# Epoch 32/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9642 - dice_coef: 0.9642 - binary_accuracy: 0.9821 - val_loss: -0.9624 - val_dice_coef: 0.9624 - val_binary_accuracy: 0.9808
#
# Epoch 00032: val_loss did not improve from -0.96255
# Epoch 33/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9645 - dice_coef: 0.9645 - binary_accuracy: 0.9822 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9808
#
# Epoch 00033: val_loss did not improve from -0.96255
# Epoch 34/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9628 - dice_coef: 0.9628 - binary_accuracy: 0.9814 - val_loss: -0.9619 - val_dice_coef: 0.9619 - val_binary_accuracy: 0.9807
#
# Epoch 00034: val_loss did not improve from -0.96255
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 35/50
# 36/36 [==============================] - 82s 2s/step - loss: -0.9643 - dice_coef: 0.9643 - binary_accuracy: 0.9817 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00035: val_loss improved from -0.96255 to -0.96287, saving model to cxr_reg_weights.best.hdf5
# Epoch 36/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9660 - dice_coef: 0.9660 - binary_accuracy: 0.9830 - val_loss: -0.9627 - val_dice_coef: 0.9627 - val_binary_accuracy: 0.9810
#
# Epoch 00036: val_loss did not improve from -0.96287
# Epoch 37/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9641 - dice_coef: 0.9641 - binary_accuracy: 0.9817 - val_loss: -0.9626 - val_dice_coef: 0.9626 - val_binary_accuracy: 0.9810
#
# Epoch 00037: val_loss did not improve from -0.96287
# Epoch 38/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9650 - dice_coef: 0.9650 - binary_accuracy: 0.9824 - val_loss: -0.9627 - val_dice_coef: 0.9627 - val_binary_accuracy: 0.9809
#
# Epoch 00038: val_loss did not improve from -0.96287
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 39/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9636 - dice_coef: 0.9636 - binary_accuracy: 0.9817 - val_loss: -0.9628 - val_dice_coef: 0.9628 - val_binary_accuracy: 0.9811
#
# Epoch 00039: val_loss did not improve from -0.96287
# Epoch 40/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9632 - dice_coef: 0.9632 - binary_accuracy: 0.9816 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00040: val_loss did not improve from -0.96287
# Epoch 41/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9655 - dice_coef: 0.9655 - binary_accuracy: 0.9825 - val_loss: -0.9628 - val_dice_coef: 0.9628 - val_binary_accuracy: 0.9811
#
# Epoch 00041: val_loss did not improve from -0.96287
# Epoch 42/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9652 - dice_coef: 0.9652 - binary_accuracy: 0.9824 - val_loss: -0.9631 - val_dice_coef: 0.9631 - val_binary_accuracy: 0.9812
#
# Epoch 00042: val_loss improved from -0.96287 to -0.96309, saving model to cxr_reg_weights.best.hdf5
# Epoch 43/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9666 - dice_coef: 0.9665 - binary_accuracy: 0.9833 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00043: val_loss did not improve from -0.96309
# Epoch 44/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9649 - dice_coef: 0.9649 - binary_accuracy: 0.9826 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00044: val_loss did not improve from -0.96309
# Epoch 45/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9651 - dice_coef: 0.9651 - binary_accuracy: 0.9825 - val_loss: -0.9627 - val_dice_coef: 0.9627 - val_binary_accuracy: 0.9810
#
# Epoch 00045: val_loss did not improve from -0.96309
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 46/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9660 - dice_coef: 0.9660 - binary_accuracy: 0.9830 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00046: val_loss did not improve from -0.96309
# Epoch 47/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9652 - dice_coef: 0.9652 - binary_accuracy: 0.9825 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00047: val_loss did not improve from -0.96309
# Epoch 48/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9652 - dice_coef: 0.9652 - binary_accuracy: 0.9825 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9811
#
# Epoch 00048: val_loss did not improve from -0.96309
# Epoch 49/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9651 - dice_coef: 0.9651 - binary_accuracy: 0.9825 - val_loss: -0.9631 - val_dice_coef: 0.9631 - val_binary_accuracy: 0.9812
#
# Epoch 00049: val_loss did not improve from -0.96309
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 50/50
# 36/36 [==============================] - 83s 2s/step - loss: -0.9658 - dice_coef: 0.9658 - binary_accuracy: 0.9830 - val_loss: -0.9630 - val_dice_coef: 0.9630 - val_binary_accuracy: 0.9811
#
# Epoch 00050: val_loss did not improve from -0.96309

# %%
# plot validation and training loss/accuracy 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %%
# Visualize output
pred_candidates = np.random.randint(1,test_vol.shape[0],10)
preds = model.predict(test_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)
    
    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")
    
    
    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")
    
    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Prediction")
